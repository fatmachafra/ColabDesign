# %%
from Bio import PDB
import numpy as np

def count_and_record_contacts_for_residue(pdb_file, chain_id, residue_id, distance_threshold=5.0):
    # Load the PDB file
    parser = PDB.PDBParser(QUIET=True)
    structure = parser.get_structure("protein", pdb_file)

    # Get the specified residue
    target_residue = None
    for model in structure:
        for chain in model:
            if chain.id == chain_id:
                for residue in chain:
                    if residue.id[1] == residue_id:
                        target_residue = residue
                        print(target_residue)
                        break
                if target_residue:
                    break
        if target_residue:
            break

    if not target_residue:
        raise ValueError("Specified residue not found")

    # Analyze contacts for each atom in the residue
    all_contacts = {}  # Dictionary to store contacts for each atom
    for target_atom in target_residue:
        contact_count = 0
        contact_details = []  # List to store details of contacting atoms

        for atom in structure.get_atoms():
            if atom != target_atom:  # Avoid self-contact
                distance = np.linalg.norm(atom.coord - target_atom.coord)
                if distance <= distance_threshold:
                    contact_count += 1
                    # Record chain ID, residue ID, and atom name of contacting atom
                    parent_residue = atom.get_parent()
                    parent_chain = parent_residue.get_parent()
                    contact_details.append([
                        parent_chain.id,       # Chain ID
                        parent_residue.id[1],  # Residue ID (sequence number)
                        atom.name,              # Atom name
                        distance 
                        ])

        # Store results for this atom
        all_contacts[target_atom.name] = {
            "contact_count": contact_count,
            "contact_details": contact_details
        }

    return all_contacts

# %%
# Example usage
pdb_file = "/usr/users/fatma.chafra01/ColabDesign/af/examples/8ee2_4/8ee2_4_singlept_semigreedy_adam_0_0_1_0.005_models_1_weights_0.0_0.133_0.0_0.0_0.0_0.0_0.133_0.267_0.267_0.133_0.067_c32_use_templates_True_rm_template_ic_False_bias_True_bias_matrix_single_mutation_0th_bias_A_num_recycles_3.pdb"
chain_id = "B"
residue_id = 100
distance_threshold = 5.0

contacts_per_atom = count_and_record_contacts_for_residue(pdb_file, chain_id, residue_id, distance_threshold)

# Print results
for atom_name, data in contacts_per_atom.items():
    print(f"Atom: {atom_name}")
    print(f"  Number of contacts: {data['contact_count']}")
    print("  Contacting atoms:")
    for contact in data["contact_details"]:
        print(f"    Chain: {contact[0]}, Residue: {contact[1]}, Atom: {contact[2]}, Distance: {contact[3]}")
# Out:
# <Residue ALA het=  resseq=100 icode= >
# Atom: N
#   Number of contacts: 24
#   Contacting atoms:
#     Chain: A, Residue: 111, Atom: N, Distance: 4.682144641876221
#     Chain: A, Residue: 112, Atom: O, Distance: 4.69628381729126
#     Chain: B, Residue: 98, Atom: C, Distance: 3.794109582901001
#     Chain: B, Residue: 98, Atom: O, Distance: 3.598041296005249
#     Chain: B, Residue: 98, Atom: CG2, Distance: 4.752516746520996
#     Chain: B, Residue: 99, Atom: N, Distance: 3.386850595474243
#     Chain: B, Residue: 99, Atom: CA, Distance: 2.386460781097412
#     Chain: B, Residue: 99, Atom: C, Distance: 1.2994519472122192
#     Chain: B, Residue: 99, Atom: CB, Distance: 3.4497199058532715
#     Chain: B, Residue: 99, Atom: O, Distance: 2.2413058280944824
#     Chain: B, Residue: 99, Atom: CG, Distance: 3.5917882919311523
#     Chain: B, Residue: 99, Atom: CD1, Distance: 3.808305501937866
#     Chain: B, Residue: 100, Atom: CA, Distance: 1.460526466369629
#     Chain: B, Residue: 100, Atom: C, Distance: 2.4622085094451904
#     Chain: B, Residue: 100, Atom: CB, Distance: 2.4533188343048096
#     Chain: B, Residue: 100, Atom: O, Distance: 2.7281365394592285
#     Chain: B, Residue: 101, Atom: N, Distance: 3.6294686794281006
#     Chain: B, Residue: 101, Atom: CA, Distance: 4.885037899017334
#     Chain: B, Residue: 103, Atom: N, Distance: 4.937669277191162
#     Chain: B, Residue: 103, Atom: C, Distance: 4.983077049255371
#     Chain: B, Residue: 104, Atom: N, Distance: 4.604494571685791
#     Chain: B, Residue: 104, Atom: CA, Distance: 4.878241062164307
#     Chain: B, Residue: 104, Atom: C, Distance: 4.0451741218566895
#     Chain: B, Residue: 104, Atom: O, Distance: 2.829129695892334
# Atom: CA
#   Number of contacts: 29
#   Contacting atoms:
#     Chain: A, Residue: 109, Atom: O, Distance: 4.864082336425781
#     Chain: A, Residue: 111, Atom: N, Distance: 4.390817642211914
#     Chain: A, Residue: 111, Atom: CA, Distance: 4.742367267608643
#     Chain: A, Residue: 111, Atom: C, Distance: 4.7288408279418945
#     Chain: A, Residue: 112, Atom: N, Distance: 4.611710071563721
#     Chain: A, Residue: 112, Atom: C, Distance: 4.5062713623046875
#     Chain: A, Residue: 112, Atom: O, Distance: 3.3211419582366943
#     Chain: B, Residue: 98, Atom: O, Distance: 4.824256896972656
#     Chain: B, Residue: 99, Atom: N, Distance: 4.683189868927002
#     Chain: B, Residue: 99, Atom: CA, Distance: 3.770833730697632
#     Chain: B, Residue: 99, Atom: C, Distance: 2.4070208072662354
#     Chain: B, Residue: 99, Atom: CB, Distance: 4.683117866516113
#     Chain: B, Residue: 99, Atom: O, Distance: 2.7656047344207764
#     Chain: B, Residue: 99, Atom: CG, Distance: 4.576912879943848
#     Chain: B, Residue: 99, Atom: CD1, Distance: 4.835672855377197
#     Chain: B, Residue: 100, Atom: N, Distance: 1.460526466369629
#     Chain: B, Residue: 100, Atom: C, Distance: 1.525373935699463
#     Chain: B, Residue: 100, Atom: CB, Distance: 1.526757836341858
#     Chain: B, Residue: 100, Atom: O, Distance: 2.399993658065796
#     Chain: B, Residue: 101, Atom: N, Distance: 2.3994598388671875
#     Chain: B, Residue: 101, Atom: CA, Distance: 3.7931156158447266
#     Chain: B, Residue: 101, Atom: C, Distance: 4.383004188537598
#     Chain: B, Residue: 101, Atom: CB, Distance: 4.8211565017700195
#     Chain: B, Residue: 102, Atom: N, Distance: 4.235258102416992
#     Chain: B, Residue: 102, Atom: OG1, Distance: 4.979071140289307
#     Chain: B, Residue: 103, Atom: N, Distance: 4.716245174407959
#     Chain: B, Residue: 104, Atom: N, Distance: 4.839850902557373
#     Chain: B, Residue: 104, Atom: C, Distance: 4.818159103393555
#     Chain: B, Residue: 104, Atom: O, Distance: 3.6885757446289062
# Atom: C
#   Number of contacts: 32
#   Contacting atoms:
#     Chain: A, Residue: 15, Atom: CD1, Distance: 4.1840410232543945
#     Chain: A, Residue: 111, Atom: N, Distance: 4.574707984924316
#     Chain: A, Residue: 111, Atom: CA, Distance: 4.510270595550537
#     Chain: A, Residue: 111, Atom: C, Distance: 4.545058250427246
#     Chain: A, Residue: 111, Atom: O, Distance: 4.821732521057129
#     Chain: A, Residue: 112, Atom: N, Distance: 4.824883937835693
#     Chain: A, Residue: 112, Atom: C, Distance: 4.693509578704834
#     Chain: A, Residue: 112, Atom: O, Distance: 3.537816286087036
#     Chain: B, Residue: 99, Atom: CA, Distance: 4.460422039031982
#     Chain: B, Residue: 99, Atom: C, Distance: 3.16931414604187
#     Chain: B, Residue: 99, Atom: CB, Distance: 4.935839653015137
#     Chain: B, Residue: 99, Atom: O, Distance: 3.3170554637908936
#     Chain: B, Residue: 99, Atom: CG, Distance: 4.365848064422607
#     Chain: B, Residue: 99, Atom: CD1, Distance: 4.62478494644165
#     Chain: B, Residue: 100, Atom: N, Distance: 2.4622085094451904
#     Chain: B, Residue: 100, Atom: CA, Distance: 1.525373935699463
#     Chain: B, Residue: 100, Atom: CB, Distance: 2.504387617111206
#     Chain: B, Residue: 100, Atom: O, Distance: 1.233303189277649
#     Chain: B, Residue: 101, Atom: N, Distance: 1.309524416923523
#     Chain: B, Residue: 101, Atom: CA, Distance: 2.436371088027954
#     Chain: B, Residue: 101, Atom: C, Distance: 2.9786555767059326
#     Chain: B, Residue: 101, Atom: CB, Distance: 3.7094266414642334
#     Chain: B, Residue: 101, Atom: O, Distance: 3.9005978107452393
#     Chain: B, Residue: 101, Atom: CG, Distance: 4.962531566619873
#     Chain: B, Residue: 102, Atom: N, Distance: 3.093761920928955
#     Chain: B, Residue: 102, Atom: CA, Distance: 4.362399101257324
#     Chain: B, Residue: 102, Atom: C, Distance: 4.611507892608643
#     Chain: B, Residue: 102, Atom: OG1, Distance: 4.6387858390808105
#     Chain: B, Residue: 103, Atom: N, Distance: 3.8077611923217773
#     Chain: B, Residue: 103, Atom: CA, Distance: 4.680867671966553
#     Chain: B, Residue: 104, Atom: N, Distance: 4.743751525878906
#     Chain: B, Residue: 104, Atom: O, Distance: 4.410573482513428
# Atom: CB
#   Number of contacts: 23
#   Contacting atoms:
#     Chain: A, Residue: 112, Atom: C, Distance: 4.52192497253418
#     Chain: A, Residue: 112, Atom: O, Distance: 3.341402530670166
#     Chain: A, Residue: 113, Atom: C, Distance: 4.683964729309082
#     Chain: A, Residue: 113, Atom: O, Distance: 4.657430648803711
#     Chain: A, Residue: 114, Atom: N, Distance: 4.954065322875977
#     Chain: B, Residue: 99, Atom: CA, Distance: 4.797633171081543
#     Chain: B, Residue: 99, Atom: C, Distance: 3.6437814235687256
#     Chain: B, Residue: 99, Atom: O, Distance: 4.17999267578125
#     Chain: B, Residue: 100, Atom: N, Distance: 2.4533188343048096
#     Chain: B, Residue: 100, Atom: CA, Distance: 1.526757836341858
#     Chain: B, Residue: 100, Atom: C, Distance: 2.504387617111206
#     Chain: B, Residue: 100, Atom: O, Distance: 3.3184869289398193
#     Chain: B, Residue: 101, Atom: N, Distance: 3.05879807472229
#     Chain: B, Residue: 101, Atom: CA, Distance: 4.389131546020508
#     Chain: B, Residue: 101, Atom: C, Distance: 4.690765857696533
#     Chain: B, Residue: 102, Atom: N, Distance: 4.144881725311279
#     Chain: B, Residue: 102, Atom: OG1, Distance: 4.02872896194458
#     Chain: B, Residue: 103, Atom: N, Distance: 4.745414733886719
#     Chain: B, Residue: 104, Atom: N, Distance: 4.43813419342041
#     Chain: B, Residue: 104, Atom: CA, Distance: 4.702629566192627
#     Chain: B, Residue: 104, Atom: C, Distance: 4.444683074951172
#     Chain: B, Residue: 104, Atom: CB, Distance: 4.516477108001709
#     Chain: B, Residue: 104, Atom: O, Distance: 3.5008506774902344
# Atom: O
#   Number of contacts: 29
#   Contacting atoms:
#     Chain: A, Residue: 15, Atom: CB, Distance: 4.834254264831543
#     Chain: A, Residue: 15, Atom: CG, Distance: 4.607691287994385
#     Chain: A, Residue: 15, Atom: CD1, Distance: 4.037897109985352
#     Chain: A, Residue: 112, Atom: O, Distance: 4.756590843200684
#     Chain: B, Residue: 99, Atom: CA, Distance: 4.2960309982299805
#     Chain: B, Residue: 99, Atom: C, Distance: 3.319235324859619
#     Chain: B, Residue: 99, Atom: CB, Distance: 4.480098724365234
#     Chain: B, Residue: 99, Atom: O, Distance: 3.6462066173553467
#     Chain: B, Residue: 99, Atom: CG, Distance: 3.5983943939208984
#     Chain: B, Residue: 99, Atom: CD1, Distance: 3.672545909881592
#     Chain: B, Residue: 99, Atom: CD2, Distance: 4.6311869621276855
#     Chain: B, Residue: 100, Atom: N, Distance: 2.7281365394592285
#     Chain: B, Residue: 100, Atom: CA, Distance: 2.399993658065796
#     Chain: B, Residue: 100, Atom: C, Distance: 1.233303189277649
#     Chain: B, Residue: 100, Atom: CB, Distance: 3.3184869289398193
#     Chain: B, Residue: 101, Atom: N, Distance: 2.244370460510254
#     Chain: B, Residue: 101, Atom: CA, Distance: 2.803450345993042
#     Chain: B, Residue: 101, Atom: C, Distance: 2.8892266750335693
#     Chain: B, Residue: 101, Atom: CB, Distance: 4.291436672210693
#     Chain: B, Residue: 101, Atom: O, Distance: 3.4879026412963867
#     Chain: B, Residue: 102, Atom: N, Distance: 3.0627191066741943
#     Chain: B, Residue: 102, Atom: CA, Distance: 4.110990524291992
#     Chain: B, Residue: 102, Atom: C, Distance: 3.990770101547241
#     Chain: B, Residue: 102, Atom: OG1, Distance: 4.717681884765625
#     Chain: B, Residue: 103, Atom: N, Distance: 2.990609645843506
#     Chain: B, Residue: 103, Atom: CA, Distance: 3.668581485748291
#     Chain: B, Residue: 103, Atom: C, Distance: 4.229970932006836
#     Chain: B, Residue: 104, Atom: N, Distance: 4.174349308013916
#     Chain: B, Residue: 104, Atom: O, Distance: 4.2032470703125

# %%
# total number of contacts between chains
import csv

def count_and_record_contacts_between_chains(pdb_file, chain_id_1, chain_id_2, distance_threshold=5.0, output_file='contacts.csv'):
    # Load the PDB file
    parser = PDB.PDBParser(QUIET=True)
    structure = parser.get_structure("protein", pdb_file)

    # Extract the specified chains
    chain_1 = None
    chain_2 = None
    for model in structure:
        for chain in model:
            if chain.id == chain_id_1:
                chain_1 = chain
            elif chain.id == chain_id_2:
                chain_2 = chain
        if chain_1 and chain_2:
            break

    if not chain_1 or not chain_2:
        raise ValueError("One or both specified chains not found")

    # Analyze contacts between the two chains
    contacts = []  # List to store contact details
    for residue_1 in chain_1:
        for atom_1 in residue_1:
            for residue_2 in chain_2:
                for atom_2 in residue_2:
                    distance = np.linalg.norm(atom_1.coord - atom_2.coord)
                    if distance <= distance_threshold:
                        contacts.append([
                            chain_id_1, residue_1.id[1], atom_1.name,  # Chain 1 details
                            chain_id_2, residue_2.id[1], atom_2.name,  # Chain 2 details
                            round(distance, 3)  # Distance rounded to 3 decimal places
                        ])

    # Write contacts to CSV file
    with open(output_file, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        # Write header
        writer.writerow(['chain1', 'residue1', 'atom1', 'chain2', 'residue2', 'atom2', 'distance'])
        # Write contact data
        writer.writerows(contacts)

    return contacts

# %%
# Example usage
pdb_file = "/usr/users/fatma.chafra01/ColabDesign/af/examples/8ee2_4/8ee2_4_singlept_semigreedy_adam_0_0_1_0.005_models_1_weights_0.0_0.133_0.0_0.0_0.0_0.0_0.133_0.267_0.267_0.133_0.067_c32_use_templates_True_rm_template_ic_False_bias_True_bias_matrix_single_mutation_0th_bias_A_num_recycles_3.pdb"
chain_id_1 = "A"
chain_id_2 = "B"
distance_threshold = 5.0
output_file = "test_contacts.csv"

contacts = count_and_record_contacts_between_chains(pdb_file, chain_id_1, chain_id_2, distance_threshold, output_file)

# %%
# filter all contacts that are with a specific residue
filtered_contacts = []
for contact in contacts:
    if contact[0] == 'A'
